# %%
# Update categorical data
df_Analysis = pd.concat([
    df_Analysis, 
    pd.get_dummies(df_Analysis['WEATHER']), 
    pd.get_dummies(df_Analysis['ROADCOND']), 
    pd.get_dummies(df_Analysis['LIGHTCOND']), 
    pd.get_dummies(df_Analysis['SPEEDING']),
    pd.get_dummies(df_Analysis['JUNCTIONTYPE']),
    pd.get_dummies(df_Analysis['COLLISIONTYPE'])
], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6da4ecaf0875> in <module>
#       1 # Update categorical data
# ----> 2 df_Analysis = pd.concat([
#       3     df_Analysis,
#       4     pd.get_dummies(df_Analysis['WEATHER']),
#       5     pd.get_dummies(df_Analysis['ROADCOND']),
#
# NameError: name 'pd' is not defined

# %%
df_Analysis.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-215d65ee7baf> in <module>
# ----> 1 df_Analysis.head()
#
# NameError: name 'df_Analysis' is not defined
